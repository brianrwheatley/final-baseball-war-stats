# %%
import pandas as pd
import numpy as np

# %%
# Import cleaned injury data 
raw_data = pd.read_csv('Resources/new_cleaned_injury_data.csv')

# %%
# Drop the unnamed column
raw_data = raw_data.drop("Unnamed: 0", 1)
raw_data
# Out:
# /var/folders/2d/w0_y9zt547v2y0371_wclbcm0000gn/T/ipykernel_24183/541087785.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   raw_data = raw_data.drop("Unnamed: 0", 1)
#                  Name     Team        Date     Status injury_length  \
# 0         Jeff Suppan  Brewers  2010-03-30     Placed        15-day
# 1         Josh Butler  Brewers  2010-03-30     Placed        15-day
# 2       Alberto Arias   Astros  2010-03-31     Placed        15-day
# 3       Lance Berkman   Astros  2010-03-31     Placed        15-day
# 4      Yorman Bazardo   Astros  2010-03-31     Placed        15-day
# ...               ...      ...         ...        ...           ...
# 16651       Luke Voit  Yankees  2021-09-30     Placed        10-day
# 16652       Darin Ruf   Giants  2021-09-30  Activated        10-day
# 16653    Johnny Cueto   Giants  2021-09-30  Activated        10-day
# 16654   Craig Stammen   Padres  2021-09-30  Activated        10-day
# 16655     Matt Wisler     Rays  2021-09-30  Activated        10-day
#
#                                     Injury location
# 0                       cervical disc pain      NaN
# 1                        elbow impingement    right
# 2                      rotator cuff injury      NaN
# 3                    knee injury (surgery)     left
# 4                       strained  shoulder    right
# ...                                    ...      ...
# 16651   knee inflammation (out for season)     left
# 16652                                  NaN      NaN
# 16653                                  NaN      NaN
# 16654                                  NaN      NaN
# 16655                                  NaN      NaN
#
# [16656 rows x 7 columns]

# %%
# Check data types
raw_data.dtypes
# Out:
# Name             object
# Team             object
# Date             object
# Status           object
# injury_length    object
# Injury           object
# location         object
# dtype: object

# %%
# Convert Date column type to datetime
raw_data['Date'] = pd.to_datetime(raw_data['Date'])

# %%
# Sort the dataset by names first, then by date
raw_data = raw_data.sort_values(by = ['Name', 'Date'], ascending = [True, True], na_position = 'first')
raw_data.head(20)
# Out:
#                               Name       Team       Date     Status  \
# 7476                           NaN   Mariners 2016-06-30     Placed
# 8916                           NaN     Padres 2017-06-23  Activated
# 13546                          NaN     Astros 2020-08-20     Placed
# 14543                          NaN  White Sox 2021-04-15     Placed
# 8844   (Christopher) Brian Johnson    Red Sox 2017-06-15     Placed
# 9035   (Christopher) Brian Johnson    Red Sox 2017-07-06  Activated
# 10674  (Christopher) Brian Johnson    Red Sox 2018-07-08     Placed
# 10747  (Christopher) Brian Johnson    Red Sox 2018-07-15  Activated
# 11592  (Christopher) Brian Johnson    Red Sox 2019-04-06     Placed
# 12105  (Christopher) Brian Johnson    Red Sox 2019-06-14  Activated
# 12226  (Christopher) Brian Johnson    Red Sox 2019-06-29     Placed
# 12499  (Christopher) Brian Johnson    Red Sox 2019-08-03  Activated
# 5061     (Darrell) David Carpenter     Braves 2014-06-17     Placed
# 5156     (Darrell) David Carpenter     Braves 2014-07-02  Activated
# 6189     (Darrell) David Carpenter  Nationals 2015-06-12  Activated
# 6377     (Darrell) David Carpenter  Nationals 2015-07-16     Placed
# 6640     (Darrell) David Carpenter  Nationals 2015-09-01     Placed
# 6852     (Darrell) David Carpenter  Nationals 2015-11-03  Activated
# 6211         (David) Chris Hatcher    Dodgers 2015-06-17     Placed
# 6448         (David) Chris Hatcher    Dodgers 2015-07-30     Placed
#
#       injury_length                          Injury location
# 7476         15-day                 fractured  hand    right
# 8916         10-day                             NaN      NaN
# 13546        10-day                hamstring injury    right
# 14543        10-day             strained  abdominal     left
# 8844         10-day            shoulder impingement     left
# 9035         10-day                             NaN      NaN
# 10674        10-day                hip inflammation     left
# 10747        10-day                             NaN      NaN
# 11592        10-day              elbow inflammation     left
# 12105        10-day                             NaN      NaN
# 12226        10-day  non-baseball medical condition      NaN
# 12499        10-day                             NaN      NaN
# 5061         15-day                strained  biceps    right
# 5156         15-day                             NaN      NaN
# 6189         15-day                             NaN      NaN
# 6377         15-day           shoulder inflammation    right
# 6640            NaN           shoulder inflammation    right
# 6852         60-day                             NaN      NaN
# 6211         15-day               strained  oblique     left
# 6448            NaN               strained  oblique     left

# %%
# Drop the rows that have NaN values for the name 
raw_data = raw_data.drop([14543, 13546, 8916, 7476])
raw_data.head(20)
# Out:
#                               Name       Team       Date     Status  \
# 8844   (Christopher) Brian Johnson    Red Sox 2017-06-15     Placed
# 9035   (Christopher) Brian Johnson    Red Sox 2017-07-06  Activated
# 10674  (Christopher) Brian Johnson    Red Sox 2018-07-08     Placed
# 10747  (Christopher) Brian Johnson    Red Sox 2018-07-15  Activated
# 11592  (Christopher) Brian Johnson    Red Sox 2019-04-06     Placed
# 12105  (Christopher) Brian Johnson    Red Sox 2019-06-14  Activated
# 12226  (Christopher) Brian Johnson    Red Sox 2019-06-29     Placed
# 12499  (Christopher) Brian Johnson    Red Sox 2019-08-03  Activated
# 5061     (Darrell) David Carpenter     Braves 2014-06-17     Placed
# 5156     (Darrell) David Carpenter     Braves 2014-07-02  Activated
# 6189     (Darrell) David Carpenter  Nationals 2015-06-12  Activated
# 6377     (Darrell) David Carpenter  Nationals 2015-07-16     Placed
# 6640     (Darrell) David Carpenter  Nationals 2015-09-01     Placed
# 6852     (Darrell) David Carpenter  Nationals 2015-11-03  Activated
# 6211         (David) Chris Hatcher    Dodgers 2015-06-17     Placed
# 6448         (David) Chris Hatcher    Dodgers 2015-07-30     Placed
# 6543         (David) Chris Hatcher    Dodgers 2015-08-14  Activated
# 7606         (David) Chris Hatcher    Dodgers 2016-07-20     Placed
# 7613         (David) Chris Hatcher    Dodgers 2016-07-21     Placed
# 8175         (David) Chris Hatcher    Dodgers 2016-11-07  Activated
#
#       injury_length                          Injury location
# 8844         10-day            shoulder impingement     left
# 9035         10-day                             NaN      NaN
# 10674        10-day                hip inflammation     left
# 10747        10-day                             NaN      NaN
# 11592        10-day              elbow inflammation     left
# 12105        10-day                             NaN      NaN
# 12226        10-day  non-baseball medical condition      NaN
# 12499        10-day                             NaN      NaN
# 5061         15-day                strained  biceps    right
# 5156         15-day                             NaN      NaN
# 6189         15-day                             NaN      NaN
# 6377         15-day           shoulder inflammation    right
# 6640            NaN           shoulder inflammation    right
# 6852         60-day                             NaN      NaN
# 6211         15-day               strained  oblique     left
# 6448            NaN               strained  oblique     left
# 6543         60-day                             NaN      NaN
# 7606         15-day               strained  oblique     left
# 7613            NaN               strained  oblique     left
# 8175         60-day                             NaN      NaN

# %%
# Create a new column to hold number of days on IL/DL
raw_data["time_out"] = ''
raw_data.head(20)
# Out:
#                               Name       Team       Date     Status  \
# 8844   (Christopher) Brian Johnson    Red Sox 2017-06-15     Placed
# 9035   (Christopher) Brian Johnson    Red Sox 2017-07-06  Activated
# 10674  (Christopher) Brian Johnson    Red Sox 2018-07-08     Placed
# 10747  (Christopher) Brian Johnson    Red Sox 2018-07-15  Activated
# 11592  (Christopher) Brian Johnson    Red Sox 2019-04-06     Placed
# 12105  (Christopher) Brian Johnson    Red Sox 2019-06-14  Activated
# 12226  (Christopher) Brian Johnson    Red Sox 2019-06-29     Placed
# 12499  (Christopher) Brian Johnson    Red Sox 2019-08-03  Activated
# 5061     (Darrell) David Carpenter     Braves 2014-06-17     Placed
# 5156     (Darrell) David Carpenter     Braves 2014-07-02  Activated
# 6189     (Darrell) David Carpenter  Nationals 2015-06-12  Activated
# 6377     (Darrell) David Carpenter  Nationals 2015-07-16     Placed
# 6640     (Darrell) David Carpenter  Nationals 2015-09-01     Placed
# 6852     (Darrell) David Carpenter  Nationals 2015-11-03  Activated
# 6211         (David) Chris Hatcher    Dodgers 2015-06-17     Placed
# 6448         (David) Chris Hatcher    Dodgers 2015-07-30     Placed
# 6543         (David) Chris Hatcher    Dodgers 2015-08-14  Activated
# 7606         (David) Chris Hatcher    Dodgers 2016-07-20     Placed
# 7613         (David) Chris Hatcher    Dodgers 2016-07-21     Placed
# 8175         (David) Chris Hatcher    Dodgers 2016-11-07  Activated
#
#       injury_length                          Injury location time_out
# 8844         10-day            shoulder impingement     left
# 9035         10-day                             NaN      NaN
# 10674        10-day                hip inflammation     left
# 10747        10-day                             NaN      NaN
# 11592        10-day              elbow inflammation     left
# 12105        10-day                             NaN      NaN
# 12226        10-day  non-baseball medical condition      NaN
# 12499        10-day                             NaN      NaN
# 5061         15-day                strained  biceps    right
# 5156         15-day                             NaN      NaN
# 6189         15-day                             NaN      NaN
# 6377         15-day           shoulder inflammation    right
# 6640            NaN           shoulder inflammation    right
# 6852         60-day                             NaN      NaN
# 6211         15-day               strained  oblique     left
# 6448            NaN               strained  oblique     left
# 6543         60-day                             NaN      NaN
# 7606         15-day               strained  oblique     left
# 7613            NaN               strained  oblique     left
# 8175         60-day                             NaN      NaN

# %%
# Check amount of null values across dataframe
# This is mostly to see how many NaNs are in the injujry length column because we are 
# about to drop them
raw_data.isna().sum()
# Out:
# Name                0
# Team                0
# Date                0
# Status              0
# injury_length    1828
# Injury           8179
# location         9723
# time_out            0
# dtype: int64

# %%
# drop rows with NaN in injury_length column
# These indicated when a player was upgraded from say the 15 to 60 day IL/DL
# Which we do not need to know
date_df = raw_data[raw_data['injury_length'].notna()]
date_df.head(20)
# Out:
#                               Name       Team       Date     Status  \
# 8844   (Christopher) Brian Johnson    Red Sox 2017-06-15     Placed
# 9035   (Christopher) Brian Johnson    Red Sox 2017-07-06  Activated
# 10674  (Christopher) Brian Johnson    Red Sox 2018-07-08     Placed
# 10747  (Christopher) Brian Johnson    Red Sox 2018-07-15  Activated
# 11592  (Christopher) Brian Johnson    Red Sox 2019-04-06     Placed
# 12105  (Christopher) Brian Johnson    Red Sox 2019-06-14  Activated
# 12226  (Christopher) Brian Johnson    Red Sox 2019-06-29     Placed
# 12499  (Christopher) Brian Johnson    Red Sox 2019-08-03  Activated
# 5061     (Darrell) David Carpenter     Braves 2014-06-17     Placed
# 5156     (Darrell) David Carpenter     Braves 2014-07-02  Activated
# 6189     (Darrell) David Carpenter  Nationals 2015-06-12  Activated
# 6377     (Darrell) David Carpenter  Nationals 2015-07-16     Placed
# 6852     (Darrell) David Carpenter  Nationals 2015-11-03  Activated
# 6211         (David) Chris Hatcher    Dodgers 2015-06-17     Placed
# 6543         (David) Chris Hatcher    Dodgers 2015-08-14  Activated
# 7606         (David) Chris Hatcher    Dodgers 2016-07-20     Placed
# 8175         (David) Chris Hatcher    Dodgers 2016-11-07  Activated
# 8904         (David) Chris Hatcher    Dodgers 2017-06-23     Placed
# 9319         (David) Chris Hatcher    Dodgers 2017-08-13  Activated
# 10583         (Dennis) Ryan Tepera  Blue Jays 2018-06-30     Placed
#
#       injury_length                          Injury location time_out
# 8844         10-day            shoulder impingement     left
# 9035         10-day                             NaN      NaN
# 10674        10-day                hip inflammation     left
# 10747        10-day                             NaN      NaN
# 11592        10-day              elbow inflammation     left
# 12105        10-day                             NaN      NaN
# 12226        10-day  non-baseball medical condition      NaN
# 12499        10-day                             NaN      NaN
# 5061         15-day                strained  biceps    right
# 5156         15-day                             NaN      NaN
# 6189         15-day                             NaN      NaN
# 6377         15-day           shoulder inflammation    right
# 6852         60-day                             NaN      NaN
# 6211         15-day               strained  oblique     left
# 6543         60-day                             NaN      NaN
# 7606         15-day               strained  oblique     left
# 8175         60-day                             NaN      NaN
# 8904         10-day           shoulder inflammation    right
# 9319         10-day                             NaN      NaN
# 10583        10-day              elbow inflammation    right

# %%
# calculate the difference in the date column with the value before it
# AKA, calculate how long the player was on the IL/DL
date_df['time_out'] = date_df.Date.diff()
date_df.head(20)
# Out:
# /var/folders/2d/w0_y9zt547v2y0371_wclbcm0000gn/T/ipykernel_24183/829518334.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   date_df['time_out'] = date_df.Date.diff()
#                               Name       Team       Date     Status  \
# 8844   (Christopher) Brian Johnson    Red Sox 2017-06-15     Placed
# 9035   (Christopher) Brian Johnson    Red Sox 2017-07-06  Activated
# 10674  (Christopher) Brian Johnson    Red Sox 2018-07-08     Placed
# 10747  (Christopher) Brian Johnson    Red Sox 2018-07-15  Activated
# 11592  (Christopher) Brian Johnson    Red Sox 2019-04-06     Placed
# 12105  (Christopher) Brian Johnson    Red Sox 2019-06-14  Activated
# 12226  (Christopher) Brian Johnson    Red Sox 2019-06-29     Placed
# 12499  (Christopher) Brian Johnson    Red Sox 2019-08-03  Activated
# 5061     (Darrell) David Carpenter     Braves 2014-06-17     Placed
# 5156     (Darrell) David Carpenter     Braves 2014-07-02  Activated
# 6189     (Darrell) David Carpenter  Nationals 2015-06-12  Activated
# 6377     (Darrell) David Carpenter  Nationals 2015-07-16     Placed
# 6852     (Darrell) David Carpenter  Nationals 2015-11-03  Activated
# 6211         (David) Chris Hatcher    Dodgers 2015-06-17     Placed
# 6543         (David) Chris Hatcher    Dodgers 2015-08-14  Activated
# 7606         (David) Chris Hatcher    Dodgers 2016-07-20     Placed
# 8175         (David) Chris Hatcher    Dodgers 2016-11-07  Activated
# 8904         (David) Chris Hatcher    Dodgers 2017-06-23     Placed
# 9319         (David) Chris Hatcher    Dodgers 2017-08-13  Activated
# 10583         (Dennis) Ryan Tepera  Blue Jays 2018-06-30     Placed
#
#       injury_length                          Injury location   time_out
# 8844         10-day            shoulder impingement     left        NaT
# 9035         10-day                             NaN      NaN    21 days
# 10674        10-day                hip inflammation     left   367 days
# 10747        10-day                             NaN      NaN     7 days
# 11592        10-day              elbow inflammation     left   265 days
# 12105        10-day                             NaN      NaN    69 days
# 12226        10-day  non-baseball medical condition      NaN    15 days
# 12499        10-day                             NaN      NaN    35 days
# 5061         15-day                strained  biceps    right -1873 days
# 5156         15-day                             NaN      NaN    15 days
# 6189         15-day                             NaN      NaN   345 days
# 6377         15-day           shoulder inflammation    right    34 days
# 6852         60-day                             NaN      NaN   110 days
# 6211         15-day               strained  oblique     left  -139 days
# 6543         60-day                             NaN      NaN    58 days
# 7606         15-day               strained  oblique     left   341 days
# 8175         60-day                             NaN      NaN   110 days
# 8904         10-day           shoulder inflammation    right   228 days
# 9319         10-day                             NaN      NaN    51 days
# 10583        10-day              elbow inflammation    right   321 days

# %%
# delete time_out values for rows that have 'Placed' in the Status column
# this is unnecessary info that will mess up our machine learning results if kept
for idx, row in date_df.iterrows():
    if  date_df.loc[idx,'Status'] == 'Placed':
        date_df.loc[idx,'time_out'] = ''

date_df.head(30)
# Out:
# /Users/michaelbinger/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#                               Name       Team       Date     Status  \
# 8844   (Christopher) Brian Johnson    Red Sox 2017-06-15     Placed
# 9035   (Christopher) Brian Johnson    Red Sox 2017-07-06  Activated
# 10674  (Christopher) Brian Johnson    Red Sox 2018-07-08     Placed
# 10747  (Christopher) Brian Johnson    Red Sox 2018-07-15  Activated
# 11592  (Christopher) Brian Johnson    Red Sox 2019-04-06     Placed
# 12105  (Christopher) Brian Johnson    Red Sox 2019-06-14  Activated
# 12226  (Christopher) Brian Johnson    Red Sox 2019-06-29     Placed
# 12499  (Christopher) Brian Johnson    Red Sox 2019-08-03  Activated
# 5061     (Darrell) David Carpenter     Braves 2014-06-17     Placed
# 5156     (Darrell) David Carpenter     Braves 2014-07-02  Activated
# 6189     (Darrell) David Carpenter  Nationals 2015-06-12  Activated
# 6377     (Darrell) David Carpenter  Nationals 2015-07-16     Placed
# 6852     (Darrell) David Carpenter  Nationals 2015-11-03  Activated
# 6211         (David) Chris Hatcher    Dodgers 2015-06-17     Placed
# 6543         (David) Chris Hatcher    Dodgers 2015-08-14  Activated
# 7606         (David) Chris Hatcher    Dodgers 2016-07-20     Placed
# 8175         (David) Chris Hatcher    Dodgers 2016-11-07  Activated
# 8904         (David) Chris Hatcher    Dodgers 2017-06-23     Placed
# 9319         (David) Chris Hatcher    Dodgers 2017-08-13  Activated
# 10583         (Dennis) Ryan Tepera  Blue Jays 2018-06-30     Placed
# 10745         (Dennis) Ryan Tepera  Blue Jays 2018-07-15  Activated
# 11504         (Dennis) Ryan Tepera  Blue Jays 2019-03-28     Placed
# 11660         (Dennis) Ryan Tepera  Blue Jays 2019-04-18  Activated
# 11897         (Dennis) Ryan Tepera  Blue Jays 2019-05-21     Placed
# 12745         (Dennis) Ryan Tepera  Blue Jays 2019-09-01  Activated
# 15481         (Dennis) Ryan Tepera       Cubs 2021-06-29     Placed
# 15621         (Dennis) Ryan Tepera       Cubs 2021-07-09  Activated
# 16461         (Dennis) Ryan Tepera  White Sox 2021-09-14     Placed
# 1632       (Ivan) Dereck Rodriguez      Twins 2011-07-07     Placed
# 1956       (Ivan) Dereck Rodriguez      Twins 2011-09-03  Activated
#
#       injury_length                             Injury location time_out
# 8844         10-day               shoulder impingement     left      NaT
# 9035         10-day                                NaN      NaN  21 days
# 10674        10-day                   hip inflammation     left      NaT
# 10747        10-day                                NaN      NaN   7 days
# 11592        10-day                 elbow inflammation     left      NaT
# 12105        10-day                                NaN      NaN  69 days
# 12226        10-day     non-baseball medical condition      NaN      NaT
# 12499        10-day                                NaN      NaN  35 days
# 5061         15-day                   strained  biceps    right      NaT
# 5156         15-day                                NaN      NaN  15 days
# 6189         15-day                                NaN      NaN 345 days
# 6377         15-day              shoulder inflammation    right      NaT
# 6852         60-day                                NaN      NaN 110 days
# 6211         15-day                  strained  oblique     left      NaT
# 6543         60-day                                NaN      NaN  58 days
# 7606         15-day                  strained  oblique     left      NaT
# 8175         60-day                                NaN      NaN 110 days
# 8904         10-day              shoulder inflammation    right      NaT
# 9319         10-day                                NaN      NaN  51 days
# 10583        10-day                 elbow inflammation    right      NaT
# 10745        10-day                                NaN      NaN  15 days
# 11504        10-day  sore  elbow /  elbow inflammation    right      NaT
# 11660        10-day                                NaN      NaN  21 days
# 11897        10-day                  elbow impingement    right      NaT
# 12745        60-day                                NaN      NaN 103 days
# 15481        10-day                     strained  calf     left      NaT
# 15621        10-day                                NaN      NaN  10 days
# 16461        10-day        laceration on  index finger    right      NaT
# 1632         15-day           strained  oblique muscle    right      NaT
# 1956         15-day                                NaN      NaN  58 days

# %%
# Save this dataframe as a new CSV file
date_df.to_csv("cleaned_injury_data_with_dates.csv")
