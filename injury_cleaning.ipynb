# %%
import pandas as pd
injuryCSV = "Resources/cleaned_injury_data.csv"

injury_df = pd.read_csv(injuryCSV, encoding='ISO-8859-1')
injury_df
# Out:
#        Unnamed: 0            Name        Date  \
# 0               1     Jeff Suppan  2010-03-30
# 1               2     Josh Butler  2010-03-30
# 2               3   Alberto Arias  2010-03-31
# 3               4   Lance Berkman  2010-03-31
# 4               5  Yorman Bazardo  2010-03-31
# ...           ...             ...         ...
# 16651       17318       Luke Voit  2021-09-30
# 16652       17319       Darin Ruf  2021-09-30
# 16653       17320    Johnny Cueto  2021-09-30
# 16654       17321   Craig Stammen  2021-09-30
# 16655       17322     Matt Wisler  2021-09-30
#
#                                                    Notes     Team
# 0            placed on 15-day DL with cervical disc pain  Brewers
# 1       placed on 15-day DL with right elbow impingement  Brewers
# 2           placed on 15-day DL with rotator cuff injury   Astros
# 3      placed on 15-day DL with left knee injury (sur...   Astros
# 4       placed on 15-day DL with strained right shoulder   Astros
# ...                                                  ...      ...
# 16651  placed on 10-day IL with left knee inflammatio...  Yankees
# 16652                           activated from 10-day IL   Giants
# 16653                           activated from 10-day IL   Giants
# 16654                           activated from 10-day IL   Padres
# 16655                           activated from 10-day IL     Rays
#
# [16656 rows x 5 columns]

# %%
#splitting df based on movements
placed_df = injury_df.loc[injury_df['Notes'].str.contains("placed")]
activated_df = injury_df.loc[injury_df['Notes'].str.contains("activated")]
transfer_df = injury_df.loc[injury_df['Notes'].str.contains("transferred")]
called_df = injury_df.loc[injury_df['Notes'].str.contains("called")]

# %%
placed_df['name_code'] = ""
placed_df
# Out:
# C:\Users\Brian\AppData\Local\Temp/ipykernel_16104/2716543478.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   placed_df['name_code'] = ""
#        Unnamed: 0            Name        Date  \
# 0               1     Jeff Suppan  2010-03-30
# 1               2     Josh Butler  2010-03-30
# 2               3   Alberto Arias  2010-03-31
# 3               4   Lance Berkman  2010-03-31
# 4               5  Yorman Bazardo  2010-03-31
# ...           ...             ...         ...
# 16646       17312   Austin Romine  2021-09-30
# 16647       17313     Tony Watson  2021-09-30
# 16648       17314      Yu Darvish  2021-09-30
# 16650       17317    Daniel Lynch  2021-09-30
# 16651       17318       Luke Voit  2021-09-30
#
#                                                    Notes     Team name_code
# 0            placed on 15-day DL with cervical disc pain  Brewers
# 1       placed on 15-day DL with right elbow impingement  Brewers
# 2           placed on 15-day DL with rotator cuff injury   Astros
# 3      placed on 15-day DL with left knee injury (sur...   Astros
# 4       placed on 15-day DL with strained right shoulder   Astros
# ...                                                  ...      ...       ...
# 16646        placed on 10-day IL with undisclosed injury     Cubs
# 16647    placed on 10-day IL with strained left shoulder   Giants
# 16648      placed on 10-day IL with left hip impingement   Padres
# 16650        placed on 10-day IL with bruised right hand   Royals
# 16651  placed on 10-day IL with left knee inflammatio...  Yankees
#
# [7643 rows x 6 columns]

# %%
split_placed_df = placed_df['Name'].str.split(' ', n=2, expand=True)
split_placed_df.to_csv("split_placed_df.csv")

# %%
split_placed_df[2].nunique()
# Out:
# 312

# %%
shortname_sr = (pd.Series(split_placed_df[0].str[:1])).str.lower()
lastname_sr = (pd.Series(split_placed_df[1].str[:])).str.lower()
shortname = shortname_sr + lastname_sr
shortname
# Out:
# 0         jsuppan
# 1         jbutler
# 2          aarias
# 3        lberkman
# 4        ybazardo
#            ...
# 16646     aromine
# 16647     twatson
# 16648    ydarvish
# 16650      dlynch
# 16651       lvoit
# Length: 7643, dtype: object

# %%
placed_df
placed_df['name_code'] = shortname

placed_df
# Out:
# C:\Users\Brian\AppData\Local\Temp/ipykernel_16104/1821304664.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   placed_df['name_code'] = shortname
#        Unnamed: 0            Name        Date  \
# 0               1     Jeff Suppan  2010-03-30
# 1               2     Josh Butler  2010-03-30
# 2               3   Alberto Arias  2010-03-31
# 3               4   Lance Berkman  2010-03-31
# 4               5  Yorman Bazardo  2010-03-31
# ...           ...             ...         ...
# 16646       17312   Austin Romine  2021-09-30
# 16647       17313     Tony Watson  2021-09-30
# 16648       17314      Yu Darvish  2021-09-30
# 16650       17317    Daniel Lynch  2021-09-30
# 16651       17318       Luke Voit  2021-09-30
#
#                                                    Notes     Team name_code
# 0            placed on 15-day DL with cervical disc pain  Brewers   jsuppan
# 1       placed on 15-day DL with right elbow impingement  Brewers   jbutler
# 2           placed on 15-day DL with rotator cuff injury   Astros    aarias
# 3      placed on 15-day DL with left knee injury (sur...   Astros  lberkman
# 4       placed on 15-day DL with strained right shoulder   Astros  ybazardo
# ...                                                  ...      ...       ...
# 16646        placed on 10-day IL with undisclosed injury     Cubs   aromine
# 16647    placed on 10-day IL with strained left shoulder   Giants   twatson
# 16648      placed on 10-day IL with left hip impingement   Padres  ydarvish
# 16650        placed on 10-day IL with bruised right hand   Royals    dlynch
# 16651  placed on 10-day IL with left knee inflammatio...  Yankees     lvoit
#
# [7643 rows x 6 columns]

# %%
placed_df.to_csv("placed_df.csv")
