# %%
import pandas as pd

# %%
url = 'https://baseballwar.s3.us-west-1.amazonaws.com/Resources/final_injury_data.csv'

# %%
df = pd.read_csv(url)
df
# Out:
#        Unnamed: 0           Name     Team     Date     Status injury_length  \
# 0               0  Brian Johnson  Red Sox  6/15/17     Placed        10-day
# 1               1  Brian Johnson  Red Sox   7/6/17  Activated        10-day
# 2               2  Brian Johnson  Red Sox   7/8/18     Placed        10-day
# 3               3  Brian Johnson  Red Sox  7/15/18  Activated        10-day
# 4               4  Brian Johnson  Red Sox   4/6/19     Placed        10-day
# ...           ...            ...      ...      ...        ...           ...
# 14800       14800   Zack Wheeler     Mets  11/3/17  Activated        60-day
# 14801       14801   Zack Wheeler     Mets  7/15/19     Placed        10-day
# 14802       14802   Zack Wheeler     Mets  7/26/19  Activated        10-day
# 14803       14803  Zoilo Almonte  Yankees  7/20/13     Placed        15-day
# 14804       14804  Zoilo Almonte  Yankees   9/9/13  Activated        15-day
#
# ...
